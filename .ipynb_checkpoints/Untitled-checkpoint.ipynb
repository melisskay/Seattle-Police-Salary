# %%
import pandas as pd

# %%
data = pd.read_csv("City_of_Seattle_Wage_Data.csv")

# %%
df = data[data['Department'] == 'Police Department']
df
# Out:
#               Department Last Name First Name                     Job Title  \
# 0      Police Department    Aagard       Lori                     Pol Lieut
# 1      Police Department  Aakervik        Dag            Pol Ofcr-Detective
# 10     Police Department      Abdi    Habtamu            StratAdvsr2,Exempt
# 15     Police Department      Abed     George                Pol Ofcr-Patrl
# 27     Police Department    Abraha    Ytbarek              Parking Enf Ofcr
# ...                  ...       ...        ...                           ...
# 11943  Police Department     Zuray     Joshua                  Pol Ofcr-BWV
# 11944  Police Department   Zurcher    Richard            Pol Ofcr-Patrl-BWV
# 11947  Police Department  Zwaschka     Andrew  Pol Sgt-Detective-Patrol-BWV
# 11949  Police Department  Zwerling   Fabienne            Admin Staff Anlyst
# 11952  Police Department     Zylak       Carl               Pol Ofcr-Canine
#
#        Hourly Rate
# 0             80.07
# ...

# %%
data[data['Department'] == 'Police Department']['Job Title'].value_counts().index
# Out:
# Index(['Pol Ofcr-Patrl-BWV', 'Pol Ofcr-BWV', 'Pol Ofcr-Detective',
#        'Parking Enf Ofcr', 'Pol Sgt-Patrl-BWV', 'Pol Ofcr- Student',
#        'Pol Ofcr-Patrl', 'Pol Recruit', 'Pol Comms Dispatcher I', 'Pol Lieut',
#        ...
#        'Latent Print Examiner,Sr', 'Manager1,CL&PS',
#        'Pol Capt - Violent Crime', 'Mgmt Systs Anlyst,Asst',
#        'Personnel Spec,Asst', 'Res&Eval Asst', 'Equip&Facils Coord,Sr',
#        'Personnel Spec Trne', 'Admin Spec II-BU *', 'Manager3,CL&PS'],
#       dtype='object', length=142)

# %%
# Out:
# Pol Ofcr-Patrl-BWV
# Pol Ofcr-BWV
# Pol Ofcr-Detective
# Parking Enf Ofcr
# Pol Sgt-Patrl-BWV
# Pol Ofcr- Student
# Pol Ofcr-Patrl
# Pol Recruit
# Pol Comms Dispatcher I
# Pol Lieut
# Admin Spec II-BU
# Pol Comms Dispatcher II
# Pol Sgt-Detective-Non Patrol
# Pol Data Tech
# Pol Ofcr-Diver-BWV
# Pol Ofcr-SWAT-BWV
# Pol Ofcr-Motorcycle-BWV
# Pol Ofcr-DWI-Am/Pm Enf-BWV
# Pol Comms Dispatcher Supv
# Pol Ofcr-Detective-Homicide
# Admin Spec I-BU
# Pol Ofcr-Academy Instructor
# Admin Staff Asst
# Com Svc Ofcr
# StratAdvsr2,CL&PS
# Pol Capt
# Parking Enf Ofcr Supv
# Pol Ofcr-Hostage Neg-Patrl-BWV
# Pol Comms Dispatcher III
# Admin Staff Anlyst
# Exec Asst
# Victim Advocate
# Pol Sgt-Detective-Patrol
# Pol Ofcr-Canine-BWV
# Video Spec II
# Equip&Facilities Coord
# Executive4
# StratAdvsr2,General Govt
# Admin Spec III-BU
# Latent Print Examiner
# Evidence Warehouser,Sr
# Pol Ofcr-Detective-Patrol-BWV
# Identification Data Spec
# Pol Ofcr-Detective-Bomb Squad
# Pol Comms Anlyst
# ...

# %%
data['Job Title Grouped'] =
# Out:
#                            Department Last Name  First Name  \
# 0                   Police Department    Aagard        Lori
# 1                   Police Department  Aakervik         Dag
# 2                  Parks & Recreation     Aamot     Allison
# 3            Seattle Public Utilities       Aar  Abdimallik
# 4                  Parks & Recreation      Aban     Eduardo
# ...                               ...       ...         ...
# 11948  Seattle Dept of Human Resource    Zwerin      Steven
# 11949               Police Department  Zwerling    Fabienne
# 11950                  Seattle Center  Zwerling     Sheldon
# 11951          Information Technology     Zwink      Donald
# 11952               Police Department     Zylak        Carl
#
#                    Job Title  Hourly Rate
# 0                  Pol Lieut        80.070
# 1         Pol Ofcr-Detective        60.840
# 2            Rec Attendant *        17.350
# 3       Civil Engrng Spec,Sr        54.070
# ...
